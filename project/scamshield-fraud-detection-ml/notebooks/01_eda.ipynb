# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("whitegrid")

#load the dataset
df = pd.read_csv("../data/creditcard.csv")
df[df["Class"] == 1].iloc[0]
# df.head()
# df.shape
# df.info()
# df.describe()

#class distribution
# df['Class'].value_counts()
# sns.countplot(x='Class', data=df)
# plt.title("Fraud vs Normal Transactions")
# plt.show()

#fraud percentage 
# fraud_percent = (df['Class'].sum()/len(df))*100
# fraud_percent


#transaction amount distribution is 
# plt.figure(figsize=(8,5))
# sns.histplot(df['Amount'], bins=50)
# plt.title("Transaction Amount Distribution")
# plt.show()

#fraud vs naormal amount comparison
# plt.figure(figsize=(8,5))
# sns.boxplot(x='Class', y='Amount', data=df)
# plt.title("Fraud vs Normal Transaction Amount")
# plt.show()

#Time feature distribution
# plt.figure(figsize=(8,5))
# sns.histplot(df['Time'], bins=50)
# plt.title("Transaction Time Distribution")
# plt.show()

#Correlation heatmap
# plt.figure(figsize=(12,10))
# sns.heatmap(df.corr(), cmap="coolwarm")
# plt.title("Feature Correlation Matrix")
# plt.show()

#Fraud vs normal feature comparison (example V14)
# plt.figure(figsize=(8,5))
# sns.histplot(df[df['Class']==0]['V14'], label='Normal', kde=True)
# sns.histplot(df[df['Class']==1]['V14'], label='Fraud', kde=True)

# plt.legend()
# plt.title("Feature V14 Distribution")
# plt.show()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64
